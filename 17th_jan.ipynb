# %%
a=321
big=0
while a>0:
    last=a%10
    if last>big:
        big=last
    a=a//10
print(big)
# Out:
# 3

# %%
a=102030
last=0
while a>0:
    rem=a%10
    if rem==0:
        a=a//10
        continue
    else:
        last=last*10+rem
        a=a//10
print(last)

rev1=0
while last>0:
    lasr=last%10
    rev1=rev1*10+lasr  
    last=last//10
print(rev1)
# Out:
# 321
# 123

# %%
a=1234
rev=0
while a>0:
    a
    last=a%10
    rev=rev*10+last
    a=a//10
print(rev)
# Out:
# 4321

# %%
a=12313458
last=0
while a>0:
    rem=a%10
    if rem==3:
        a=a//10
        continue
    else:
        last=last*10+rem
        a=a//10
print(last)
rev=last

rev1=0
while last>0:
    lasr=last%10
    rev1=rev1*10+lasr  
    last=last//10
print(rev1)

if rev==rev1:
    print('it is palindrome')
else:
    print('not palindrome')
# Out:
# 854121
# 121458
# not palindrome

# %%
i=5
while i>=1:
    j=1
    while j<=i:
        print(j,end='')
        j=j+1
    print()
    i=i-1
# Out:
# 12345
# 1234
# 123
# 12
# 1

# %%
i=1
while i<=5:
    j=1
    while j<=i:
        print(j, end='')
        j+=1
    print()
    i+=1
